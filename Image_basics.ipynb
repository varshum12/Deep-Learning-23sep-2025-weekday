# %% [markdown]
# <a href="https://colab.research.google.com/github/varshum12/Deep-Learning-23sep-2025-weekday/blob/main/Image_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import  cv2
path  =  '/content/CuteCat.jpeg'

# %%
A  = cv2.imread(path)

# %%
A
# Out:
# array([[[122, 108,  90],
#         [121, 107,  89],
#         [121, 107,  89],
#         ...,
#         [251, 247, 188],
#         [251, 244, 187],
#         [252, 243, 186]],
#
#        [[122, 108,  90],
#         [121, 107,  89],
#         [121, 107,  89],
#         ...,
#         [250, 247, 186],
#         [252, 246, 187],
#         [253, 244, 187]],
#
#        [[121, 107,  89],
#         [121, 107,  89],
#         [122, 108,  90],
#         ...,
#         [250, 247, 186],
#         [253, 247, 188],
#         [255, 246, 189]],
#
#        ...,
#
#        [[151, 183, 232],
#         [151, 183, 232],
#         [151, 183, 232],
#         ...,
#         [160, 175, 208],
#         [159, 174, 207],
#         [159, 174, 207]],
#
#        [[151, 183, 232],
#         [151, 183, 232],
#         [152, 184, 233],
#         ...,
#         [159, 176, 209],
#         [158, 175, 208],
#         [158, 175, 208]],
#
#        [[152, 184, 233],
#         [153, 185, 234],
#         [153, 185, 234],
# ...

# %%
#  show imag
import matplotlib.pyplot as plt
import seaborn as  sns

# %%
plt.imshow(A)

# %%
#  convert  color in  original format
Z =  cv2.cvtColor(A  , cv2.COLOR_BGR2RGB)
Z
# Out:
# array([[[ 90, 108, 122],
#         [ 89, 107, 121],
#         [ 89, 107, 121],
#         ...,
#         [188, 247, 251],
#         [187, 244, 251],
#         [186, 243, 252]],
#
#        [[ 90, 108, 122],
#         [ 89, 107, 121],
#         [ 89, 107, 121],
#         ...,
#         [186, 247, 250],
#         [187, 246, 252],
#         [187, 244, 253]],
#
#        [[ 89, 107, 121],
#         [ 89, 107, 121],
#         [ 90, 108, 122],
#         ...,
#         [186, 247, 250],
#         [188, 247, 253],
#         [189, 246, 255]],
#
#        ...,
#
#        [[232, 183, 151],
#         [232, 183, 151],
#         [232, 183, 151],
#         ...,
#         [208, 175, 160],
#         [207, 174, 159],
#         [207, 174, 159]],
#
#        [[232, 183, 151],
#         [232, 183, 151],
#         [233, 184, 152],
#         ...,
#         [209, 176, 159],
#         [208, 175, 158],
#         [208, 175, 158]],
#
#        [[233, 184, 152],
#         [234, 185, 153],
#         [234, 185, 153],
# ...

# %%
B  , R , G  =  cv2.split(Z)

# %%
B
# Out:
# array([[ 90,  89,  89, ..., 188, 187, 186],
#        [ 90,  89,  89, ..., 186, 187, 187],
#        [ 89,  89,  90, ..., 186, 188, 189],
#        ...,
#        [232, 232, 232, ..., 208, 207, 207],
#        [232, 232, 233, ..., 209, 208, 208],
#        [233, 234, 234, ..., 210, 209, 209]], dtype=uint8)

# %%
G
# Out:
# array([[122, 121, 121, ..., 251, 251, 252],
#        [122, 121, 121, ..., 250, 252, 253],
#        [121, 121, 122, ..., 250, 253, 255],
#        ...,
#        [151, 151, 151, ..., 160, 159, 159],
#        [151, 151, 152, ..., 159, 158, 158],
#        [152, 153, 153, ..., 160, 159, 159]], dtype=uint8)

# %%
R
# Out:
# array([[108, 107, 107, ..., 247, 244, 243],
#        [108, 107, 107, ..., 247, 246, 244],
#        [107, 107, 108, ..., 247, 247, 246],
#        ...,
#        [183, 183, 183, ..., 175, 174, 174],
#        [183, 183, 184, ..., 176, 175, 175],
#        [184, 185, 185, ..., 177, 176, 176]], dtype=uint8)

# %%
plt.imshow(B)

# %%
#  gray scale
C  =  cv2.imread(path ,  cv2.IMREAD_GRAYSCALE)

# %%
C
# Out:
# array([[104, 103, 103, ..., 230, 228, 227],
#        [104, 103, 103, ..., 229, 229, 228],
#        [103, 103, 104, ..., 229, 230, 230],
#        ...,
#        [194, 194, 194, ..., 183, 182, 182],
#        [194, 194, 195, ..., 184, 183, 183],
#        [195, 196, 196, ..., 185, 184, 184]], dtype=uint8)
